# %%
import numpy as np
import pandas as pd
#import scipy.stats as st
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Import and parse the data into a manipulatable dataset aka df or dataframe
xl = pd.ExcelFile("C:/Users/culle/Documents/Data/UThHe_Data/ZHe_Kortyna_TO_sum.xlsx")
#xl = pd.ExcelFile("C:/Users/culle/Documents/Data/UThHe_Data/ZHe_Kortyna_STX_sum.xlsx")
df = xl.parse("ZrHe")#, index_col=1) #index_col=0 selects which column to index the rows based on
#df.set_index("Formation", inplace = True) #does same thing as index_col=0 above - sets the index column for the df; inplace = True makes it permananet

#Perform any of below functions to see what's in the dataframe
#df.columns #shows column headers
df[:10] #lists first 10 rows
# Out:
#             Sample Sample_ID Sample_ID_V          Formation  \
# 0  zDD-16To-13-105   16TO-13     16TO-13              Canoe
# 1   zDD-16To-13-40   16TO-13     16TO-13              Canoe
# 2   zDD-16To-13-36   16TO-13     16TO-13              Canoe
# 3   zDD-16To-13-59   16TO-13    Volcanic              Canoe
# 4   zDD-16To-08-82   16TO-08     16TO-08  Upper Black Peaks
# 5  zDD-16To-08-120   16TO-08     16TO-08  Upper Black Peaks
# 6  zDD-16To-08-123   16TO-08     16TO-08  Upper Black Peaks
# 7   zDD-16To-08-57   16TO-08    Volcanic  Upper Black Peaks
# 8   zDD-16To-02-16   16TO-02     16TO-02  Lower Black Peaks
# 9   zDD-16To-02-79   16TO-02     16TO-02  Lower Black Peaks
#
#          Formation_V        Age      Age_V Volcanic? sample_if_func  \
# 0              Canoe     Eocene     Eocene        No         Eocene
# 1              Canoe     Eocene     Eocene        No         Eocene
# 2              Canoe     Eocene     Eocene        No         Eocene
# ...

# %%
#Couldn't get around this.. needed to set the index to "Formation" for the df.loc func to work, but for some reason the for i in range len(sampleList): for loop then can't find it..
df2 = xl.parse("ZrHe")#, index_col=1) #index_col=0 selects which column to index the rows based on
df2.set_index("Formation_V", inplace = True) #does same thing as index_col=0 above - sets the index column for the df; inplace = True makes it permananet

df2[:10]
# Out:
#                             Sample Sample_ID Sample_ID_V          Formation  \
# Formation_V
# Canoe              zDD-16To-13-105   16TO-13     16TO-13              Canoe
# Canoe               zDD-16To-13-40   16TO-13     16TO-13              Canoe
# Canoe               zDD-16To-13-36   16TO-13     16TO-13              Canoe
# Volcanic            zDD-16To-13-59   16TO-13    Volcanic              Canoe
# Upper Black Peaks   zDD-16To-08-82   16TO-08     16TO-08  Upper Black Peaks
# Upper Black Peaks  zDD-16To-08-120   16TO-08     16TO-08  Upper Black Peaks
# Upper Black Peaks  zDD-16To-08-123   16TO-08     16TO-08  Upper Black Peaks
# Volcanic            zDD-16To-08-57   16TO-08    Volcanic  Upper Black Peaks
# Lower Black Peaks   zDD-16To-02-16   16TO-02     16TO-02  Lower Black Peaks
# Lower Black Peaks   zDD-16To-02-79   16TO-02     16TO-02  Lower Black Peaks
#
#                          Age      Age_V Volcanic? sample_if_func     Age_He  \
# Formation_V
# ...

# %%
#let's you see all the unique values in a specified column, useful to run if you don't know all the options in a column

#samples = np.unique(df['Sample_ID'])

samples = np.unique(df['Formation'])
                 
samples
# Out:
# array(['Aguja', 'Canoe', 'Hannold Hill', 'Lower Black Peaks',
#        'Upper Black Peaks'], dtype=object)

# %%
sampleList = ['Aguja','Lower Black Peaks', 'Upper Black Peaks', 'Hannold Hill', 'Canoe']#, 'Volcanic']

#sampleList = ['Kincaid', 'Indio', 'Carrizo', 'Bigford', 'El Pico Clay', 'Laredo', 'Volcanic']

sampleList
# Out:
# ['Aguja', 'Lower Black Peaks', 'Upper Black Peaks', 'Hannold Hill', 'Canoe']

# %%
#df2.set_index("Grain_ID", inplace = True)
x = []
y = []
X_error = []
Y_error = []

for i in range(len(sampleList)): 
    x.append(df.loc[df['Formation']==sampleList[i]]['Age_UPb'])
    y.append(df.loc[df['Formation']==sampleList[i]]['Age_He'])
    X_error.append(df.loc[df['Formation']==sampleList[i]]['Age_UPb_err'])
    Y_error.append(df.loc[df['Formation']==sampleList[i]]['Age_He_err'])

#for i in range(len(sampleList)): 
#    x.append(df.loc[df['Formation_V']==sampleList[i]]['Age_UPb'])
#    y.append(df.loc[df['Formation_V']==sampleList[i]]['Age_He'])
#    X_error.append(df.loc[df['Formation_V']==sampleList[i]]['Age_UPb_err'])
#    Y_error.append(df.loc[df['Formation_V']==sampleList[i]]['Age_He_err'])
    
#    print (x, y)
#    print (x)
#    plt.plot(x, y, marker='o', linestyle="")

#plt.plot(x, y)
x
#y
#X_error
# Out:
# [82     75.6
#  83     75.3
#  84     78.3
#  85     96.1
#  86     99.3
#  87     98.6
#  88    157.4
#  89    158.2
#  90    252.4
#  91    256.4
#  92    442.7
#  93    440.3
#  94    457.6
#  95    438.4
#  Name: Age_UPb, dtype: float64, 8       67.70
#  9       94.50
#  10      97.00
#  11      71.36
#  54      68.70
#  55      67.90
#  56      80.80
#  57      98.40
#  58     101.20
#  59     191.30
#  60     158.30
#  61     164.40
#  62     275.80
#  63     283.20
#  64     293.30
#  65    1686.00
#  66    1592.00
#  67    1677.00
#  Name: Age_UPb, dtype: float64, 4       73.40
#  5       77.80
#  6       65.83
#  7       75.80
#  12      65.24
#  13      79.20
#  14      79.50
#  15      94.00
#  16     100.20
#  17      91.50
#  18     159.10
#  19     171.30
#  20     156.40
#  21     420.60
#  22     431.00
#  23    1671.00
#  24    1691.00
#  25    1601.00
#  68      70.42
#  69      79.10
#  70      79.20
#  71      80.70
#  72      99.60
#  73      92.60
# ...

# %%
for i in range(len(x)):
    plt.plot((x[i]),(y[i]),'o')

# %%
#Prep the Bivariate KDE you want

df3 = df2.loc[sampleList]
fig, ax1 = plt.subplots(figsize=(15, 10))
ax = sns.kdeplot(df3['Age_UPb'], df3['Age_He'], bw=75, cmap='Blues', shade=True, shade_lowest=False, n_levels=100, cbar=False)

#Play with a joint plot if you want, they're pretty cool!
#lol = sns.jointplot(df3['BestAge_Core'], df3['BestAge_Rim'])

# %%
#Plot the Bivariate KDE

#Plot set-up
df3 = df2.loc[sampleList] #updates df3 for bivariate KDE

fig, ax = plt.subplots(figsize=(15, 10)) #makes a fig to plot on; ax = plot; if you do ax1, ax2, etc. you'll have multiple plots

#Plot the bivariate KDE you want
#ax = sns.kdeplot(df3['BestAge_Core'], df3['BestAge_Rim'], bw=75, cmap='Blues_d', shade=False, shade_lowest=False)
#ax = sns.kdeplot(df3['BestAge_Core'], df3['BestAge_Rim'], bw=75, cmap='Blues', shade=True, shade_lowest=True, n_levels=100)
#note seaborn only supports gaussian kernels for bivariate kdes

#1:1 line
ax.fill((0,400,400),(0,432,368), color='firebrick', alpha=0.2)
ax.plot((0,3000),(0,3000), color='firebrick')
ax.plot((0,400),(0,368), color='firebrick', linestyle='dashed', alpha=0.2)
ax.plot((0,400),(0,432), color='firebrick', linestyle='dashed', alpha=0.2)
ax.plot((0,400), (-10,390), color='black', linestyle='dashed')
ax.plot((0,400), (-20, 380), color='black', linestyle='dashed')
ax.plot((0,400), (-30, 370), color='black', linestyle='dashed')

#Plot the scatterplot
for i in range(len(x)):
    colors = ['#bd0026','#f03b20', '#fd8d3c', '#fecc5c', '#ffffb2']
    #colors = plt.cm.YlOrRd_r(np.linspace(0,1,len(sampleList)))
    #colors = plt.cm.GnBu_r(np.linspace(0,1,len(sampleList)))
    #colors = plt.cm.Set1_r(np.linspace(0,1,len(sampleList)))
    markers = ['o','v','^','d','P','p','X']
    labels = ['Aguja','Lower Black Peaks', 'Upper Black Peaks', 'Hannold Hill', 'Canoe']#, 'Volcanic']
    #labels = ['Kincaid', 'Indio', 'Carrizo', 'Bigford', 'El Pico Clay', 'Laredo', 'Volcanic']
    ax.errorbar((x[i]), (y[i]), xerr=(X_error[i]), yerr=(Y_error[i]), linestyle="", color='black', capsize=0)
    #ax.plot(x, y, marker='o', markersize=7, markeredgewidth=1, markerfacecolor='White', markeredgecolor='Black', linestyle="")
    #ax.plot((x[i]), (y[i]), marker='o', markersize=7, markeredgewidth=1, markerfacecolor='white', markeredgecolor='Black', linestyle="")
    #ax.scatter((x[i]), (y[i]), marker='o', color=(colors[i]), edgecolor='black')
    ax.plot((x[i]), (y[i]), marker=(markers[i]), markersize=12, color=(colors[i]), markeredgecolor='black', alpha=1, linestyle="", label=(labels[i]))
    #ax.set_xlim(0, 2000)
    #ax.set_ylim(0, 700)
    #ax.set_xlim(0, 500)
    #ax.set_ylim(0, 300)
    ax.set_xlim(40, 130)
    ax.set_ylim(40, 105)
    
    #Choose the Bivariate KDE plot you want
    
    # Kernel density estimate plot instead of the contourf plot
    #ax.imshow(np.rot90(Z), cmap='Blues', extent=[xmin, xmax, ymin, ymax])
    #benefits of KDE plot is not biased by contour interval
    
    # Contourf plot (instead of the kernel density estimate plot) - can look cleaner
    #cfset = ax.contourf(xx, yy, Z, cmap='Blues')
    # contourf(x values, y values, Z values, number of contour intervals - deleted for automatic determination, color map choice)
    
    # Add contour lines if you wish
    #cset = ax.contour(xx, yy, Z, colors='gray')
    
# Label plot
#ax.clabel(cset, inline=1, fontsize=10)
ax.set_title ("Tornillo Zr (U-Th)/Pb-He Ages")
ax.set_xlabel('Zr U-Pb Age (Ma)')
ax.set_ylabel('Zr (U-Th)/He Age (Ma)')
ax.legend()

#Gets rid of top and right borders if you want
#ax.spines['top'].set_visible(False)
#ax.spines['right'].set_visible(False)

#plt.show()

# %%
import pathlib

# %%
pathlib.Path('Output').mkdir(parents=True, exist_ok=True) # Recursively creates the directory and does not raise an exception if the directory already exists 
fig.savefig('Output/ZHE_TO_Lag_Time3.pdf')

# %%
#Some Options for Playing around with Groupby to see how it works

#Use if using Groupby
df2 = df.loc[sampleList]
#df2.set_index("Sample_ID", inplace = True)

#df2

#grouped = df.groupby('Sample_ID')
#grouped.groups
#grouped.first()
#grouped.get_group('17STX-01')
#for name,group in grouped:
#    print (name)
#    print (group)

fig, ax = plt.subplots(figsize=(15, 10))
#S = df2.groupby('Sample_ID').plot(kind='scatter', x='BestAge_Core', y='BestAge_Rim', color='Green', ax=ax)
T = df2.groupby('Sample_ID').plot(kind='scatter', x='BestAge_Core', y='BestAge_Rim', marker='o', colormap='Paired', colorbar=False, xerr='BestAge_err_Core', yerr='BestAge_err_Rim', ax=ax)

#x = df2.groupby('Sample_ID')['BestAge_Core']
#y = df2.groupby('Sample_ID')['BestAge_Rim']
#X_error = df2.groupby('Sample_ID')['BestAge_err_Core']
#Y_error = df2.groupby('Sample_ID')['BestAge_err_Rim']

#print (x)
#plt.plot(x, y, marker='o', linestyle="")

#x.get_group('17STX-01')
#for name,group in x:
#    print (name)
#    print (group)

# %%
#Old bivariate KDE using SciPy

#Set up the dataframe for KDE
df3 = df2.loc[sampleList]
x1 = df3['BestAge_Core']
y1 = df3['BestAge_Rim']
xmin, xmax = 0, 3500
ymin, ymax = 0, 2000

#Perform the kernel density estimate on the data
xx, yy = np.mgrid[xmin:xmax:100j, ymin:ymax:100j]
positions = np.vstack([xx.ravel(), yy.ravel()])
values = np.vstack([x1, y1])
kernel = st.gaussian_kde(values)
#Note gaussian_kde uses normally distributed aka Gaussian kernels to perform the density estimation
#Also note that this works best for unimodal distributions; bimodal or multi-modal distributions tend to be oversmoothed
kernel.set_bandwidth(bw_method=0.15)
#bandwidth selection has the strongest influence on the resulting plot
#options include 'scott' which uses Scott's Rule, 'silverman' which uses Silverman's Rule, or a scalar value
#if no bandwidth is specified (i.e., the set_bandwidth is # out) then the estimation automatically uses Scott's Rule
Z = np.reshape(kernel(positions).T, xx.shape)

# %%
#old for loop for selecting x, y, x_error, y_error by Sample_ID - been replaced by pandas.df.groupby function

#for i in range(len(sampleList)): 
#    x = df.loc[df['Sample_ID']==sampleList[i]]['BestAge_Core']
#    y = df.loc[df['Sample_ID']==sampleList[i]]['BestAge_Rim']
#    X_error = df.loc[df['Sample_ID']==sampleList[i]]['BestAge_err_Core']
#    Y_error = df.loc[df['Sample_ID']==sampleList[i]]['BestAge_err_Rim']
#    print (x, y)
#    plt.plot(x, y, marker='o', linestyle="")
#problem is for loop x's don't translate outside of for loop? how do I do this?
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Sample_ID'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-29-55047eaecc7b> in <module>
#       2
#       3 for i in range(len(sampleList)):
# ...

# %%
#This little bit of code takes a series of string names, and converts them to color values depending on the color map chosen equally spaced on a line between 0 and 1.
#cmap = plt.get_cmap('gist_rainbow')
#names = ["17STX-01","17STX-02","17STX-06","17STX-07","17STX-08","17STX-09","17STX-10","17STX-11","17STX-12","17STX-13","17STX-14","17STX-15","17STX-16","17STX-17","17STX-18","17STX-19","17STX-20","17STX-22","17STX-23"]
#colors = cmap(np.linspace(0, 1, len(names)))
#print(colors)
